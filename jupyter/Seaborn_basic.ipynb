# %% [markdown]
# <span style="color:blue">**SEABORN LINEPLOTS** </span>

# %% [markdown]
# **Example 1 :**
#
# #### FIFA DATA ####

# %%
#%matplotlib inline sets the backend of matplotlib to the 'inline' backend: 
#With this backend, the output of plotting commands is displayed inline within frontends

# %%
import pandas as pd  
import seaborn as sns
import matplotlib.pyplot as plt
import pandas.plotting
# %matplotlib inline 
#pd.plotting_register_matplotlib_converters()
print('setup complete')
# Out:
# setup complete

# %%
#Path of file to read
fifa_file_path = "C:/Users/Dell/git-practice/resources/fifa.csv"

#Read the file in a variable fifa_data
fifa_data = pd.read_csv(fifa_file_path, index_col='Date', parse_dates=True)

#By default pandas will use the first column as index while importing csv file with read_csv() , 
#so if your datetime column isn't first you will need to specify it explicitly index_col='date'

#parse.dates ( recognize the row level as dates)

# %%
fifa_data.head() #chek the data loaded
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %%
# set the width and height of figure
plt.figure(figsize=(16,6))

#Line chart showing FIFA rankings over time
sns.lineplot(data=fifa_data)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ***which countries spent at least 5 consecutive years in the #1 ranked spot?**

# %% [markdown]
# **Solution:** The only country that meets this criterion is Brazil (code: BRA), as it maintains the highest ranking in 1996-2000

# %% [markdown]
# **Example 2 :**
#
# #### SPOTIFY STREAMING DATA ####

# %%
spotify_file_path = "C:/Users/Dell/git-practice/resources/spotify.csv"
spotify_data = pd.read_csv(spotify_file_path, index_col="Date", parse_dates=True)

# %%
spotify_data.head()

#Empty entries will appear as NaN, which is short for "Not a Number"
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
# 2017-01-08      13099919        NaN                       NaN      NaN
# 2017-01-09      14506351        NaN                       NaN      NaN
# 2017-01-10      14275628        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN

# %%
spotify_data.tail()
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2018-01-05      2869783.0
# 2018-01-06      2743748.0
# 2018-01-07      2441045.0
# 2018-01-08      2622693.0
# 2018-01-09      2627334.0

# %%
spotify_data.dtypes
# Out:
# Shape of You                  int64
# Despacito                   float64
# Something Just Like This    float64
# HUMBLE.                     float64
# Unforgettable               float64
# dtype: object

# %%
# Lets see the plot of streams data over time
plt.figure(figsize=(16,8))
plt.title("Daily Global Streams of Popular Songs in 2017-2018")
sns.lineplot(data=spotify_data)
# Out:
# <AxesSubplot:title={'center':'Daily Global Streams of Popular Songs in 2017-2018'}, xlabel='Date'>

# %%
list(spotify_data.columns) # List the columns
# Out:
# ['Shape of You',
#  'Despacito',
#  'Something Just Like This',
#  'HUMBLE.',
#  'Unforgettable']

# %%
# Lets compare data between two songs
plt.figure(figsize=(16,8))
sns.lineplot(data=spotify_data['Despacito'], label='Despacito')
sns.lineplot(data=spotify_data['Something Just Like This'], label='Something just like this')
plt.title("Comparison between two songs")
plt.xlabel("Dates")
# Out:
# Text(0.5, 0, 'Dates')

# %% [markdown]
# **EXAMPLE 3 :**
#
# #### MUSEUM DATA ####

# %%
# Lets assume you are hired to manage 4 museums 
# Lets import data of visitors over time in each museum

museum_d_path = "C:/Users/Dell/git-practice/resources/museum_visitors.csv"
museum_data = pd.read_csv(museum_d_path, index_col='Date', parse_dates=True)
museum_data.head() # Review the data 
#museum_data.tail()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2014-01-01        24778              4486                     1581
# 2014-02-01        18976              4172                     1785
# 2014-03-01        25231              7082                     3229
# 2014-04-01        26989              6756                     2129
# 2014-05-01        36883             10858                     3676
#
#             America Tropical Interpretive Center
# Date
# 2014-01-01                                  6602
# 2014-02-01                                  5029
# 2014-03-01                                  8129
# 2014-04-01                                  2824
# 2014-05-01                                 10694

# %% [markdown]
# **Question : How many visitors did the Chinese American Museum receive in July 2018?**

# %%
# lets first check the tail of data
museum_data.tail()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2018-07-01        23136              4191                     2620
# 2018-08-01        20815              4866                     2409
# 2018-09-01        21020              4956                     2146
# 2018-10-01        19280              4622                     2364
# 2018-11-01        17163              4082                     2385
#
#             America Tropical Interpretive Center
# Date
# 2018-07-01                                  4718
# 2018-08-01                                  3891
# 2018-09-01                                  3180
# 2018-10-01                                  3775
# 2018-11-01                                  4562

# %%
# We can see the answer is 2620 
# But lets get it from pandas 

c_museum_jul18 = museum_data['Chinese American Museum'].filter(like = '2018-07-01', axis=0) # Date is index column
print(c_museum_jul18)
# Out:
# Date
# 2018-07-01    2620
# Name: Chinese American Museum, dtype: int64
# 2620

# %% [markdown]
# **Question : In October 2018, how many more visitors did Avila Adobe receive than the Firehouse Museum?**

# %%
# we can again get the answer by seeing the tail of data Ans : Avila(17163) - Firehouse(4082) = 14658
# Lets try to get it from pandas

diff_museum_oct18 = (int(museum_data['Avila Adobe'].filter(like='2018-10-01', axis=0)))-(int(museum_data['Firehouse Museum'].filter(like ='2018-10-01', axis=0)))
#The axis to filter on, expressed either as an index (int) or axis name (str)

print(diff_museum_oct18)
# Out:
# 14658

# %%
# Let's plot Line chart showing the number of visitors to each museum over time

plt.figure(figsize=(16,6))
sns.lineplot(data=museum_data)
plt.title("Visitors over time")
plt.ylabel("Total number of visitors")
# Out:
# Text(0, 0.5, 'Total number of visitors')

# %% [markdown]
# **Case Study :**
# *When meeting with the employees at Avila Adobe, you hear that one major pain point is that the number of museum visitors varies greatly with the seasons, with low seasons (when the employees are perfectly staffed and happy) and also high seasons (when the employees are understaffed and stressed). You realize that if you can predict these high and low seasons, you can plan ahead to hire some additional seasonal employees to help out with the extra work.*

# %%
# lets plot only Avila Adobe data

plt.figure(figsize=(16,6))
sns.lineplot(data=museum_data['Avila Adobe'])
plt.title("Visitors variation at Avila Adobe")
plt.ylabel("No. of visitors")
# Out:
# Text(0, 0.5, 'No. of visitors')

# %% [markdown]
# **Question**
#
# Does Avila Adobe get more visitors:
#
# * in September-February (in LA, the fall and winter months), or
# * in March-August (in LA, the spring and summer)?

# %%
# Solution :

#The line chart generally dips to relatively low values around the early part of each year (in December and January), 
#and reaches its highest values in the middle of the year (especially around May and June). 
#Thus, Avila Adobe usually gets more visitors in March-August (or the spring and summer months). 
#With this in mind, Avila Adobe could definitely benefit from hiring more seasonal employees 
#to help with the extra work in March-August (the spring and summer)!
